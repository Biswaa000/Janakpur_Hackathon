# %%
# !pip install -U langchain-huggingface

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
import os

# %%
from google.colab import userdata
HUGGINGFACEHUB_API_TOKEN = userdata.get('HUGGINGFACEHUB_API_TOKEN')

# %%
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.2",
    # repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
    huggingfacehub_api_token=HUGGINGFACEHUB_API_TOKEN
)
chat_model = ChatHuggingFace(llm=llm)
response = chat_model.invoke("What is photosynthesis?")
print(response)
# Out:
# content=' Photosynthesis is a vital biological process used by plants and some other organisms, such as algae and certain bacteria, to convert carbon dioxide from the air and water from the soil into glucose, or sugar, and release oxygen as a byproduct. This process occurs in the chloroplasts, which contain the green pigment chlorophyll. Light energy, primarily from the sun, is absorbed by the chlorophyll and used to convert water and carbon dioxide into glucose and oxygen through a series of chemical reactions. This process provides the energy and nutrients necessary for the growth of the plant, while also releasing oxygen, which is essential for most forms of life.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 150, 'prompt_tokens': 10, 'total_tokens': 160}, 'model_name': 'mistralai/Mistral-7B-Instruct-v0.2', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--212d7c01-4720-4be5-a18a-724b7f99a23a-0' usage_metadata={'input_tokens': 10, 'output_tokens': 150, 'total_tokens': 160}
